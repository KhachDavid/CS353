# %% [markdown]
# # HW1 - Learning the basics!
#
# - This is the final graded part of Homework 1. You should first read the Environment Setup guide.
#
# - In this homework we will fill the function definitions inside 'functions.py' and import them here to check if they are working as expected.
#
# - Finally we will learn how to use the autograder.

# %%
import importlib

import numpy as np
import matplotlib.pyplot as plt

import f # this is the file that contains the functions that you will be implementing.

import autograder # you can call autograder.autograde() anytime to check your progress!

# %% [markdown]
# ---
# ## Part 1 - Loading and displying the image (10 Pts)
#
# In this part we will implement two functions inside 'f.py':<br>
# &nbsp; &nbsp; i - 'loadCameraman': loads the cameraman image at a specified resolution.<br>
# &nbsp; &nbsp; ii - 'displayGray': prints the image to the jupyter noteboook<br>
# See functions.py for more information. Once you are done run the code block below.

# %%
importlib.reload(f) # this is useful to reload the file if you make changes to it.
img = f.loadCameraman((128, 128))
f.displayGray(img)

# %% [markdown]
# ## Part 2 - Filtering an Image (20 Pts)
#
# In this part we will create a normalized 2D gaussian kernel. Later we will use this kernel to filter our image.
#
# &nbsp; &nbsp; i - Implement 'generate2DGaussianKernel' in 'f.py'. To learn more about the gaussian kernel: https://en.wikipedia.org/wiki/Gaussian_function#Two-dimensional_Gaussian_function<br>
# &nbsp; &nbsp; ii - Implement 'spatial2DConvolution' in 'f.py' <br>

# %%
importlib.reload(f)
kernel = f.generate2DGaussianKernel((15,15), 3)
f.displayGray(kernel)
filtered_image = f.spatial2DConvolution(img, kernel)
f.displayGray(filtered_image)

# %% [markdown]
# ## Part 3 - Brightness Histogram (20 Pts)
#
# In this part we will create an histogram plot. The function you need to implement is 'brightnessHist' in 'f.py'.

# %%
importlib.reload(f)
f.brightnessHist(img)

# %% [markdown]
# ---
# ## Part 4 - Ray Optics Simulator (25 Pts):
#
# Use the [ray optics simulator](https://phydemo.app/ray-optics/simulator/) to model one of the eyes that we went over in class. Explain your model and include a screenshot of your model below. Submit the json file generated when you ask the site to save your work.

# %% [markdown]
# ---
#
# ## Part 5 - Bookkeeping (25 points):
#
# **Final project brainstorm:** Based on your reading, your independent interests, and the variety of eyes we discussed in class, what visual system do you think you'd like to do your final project on? This decision is not binding, but you should be starting to make plans.
#
# **Undergrad/Gradute:**
#
# **Estimated time spent on this assignment, including reading:**
#
# **Suggestions:**

# %% [markdown]
# ## Before Submitting your work
#
# Use the autograder to test your implementations inside 'f.py'. Note that your plots will be graded manually.
#
# You are free to modify and add/remove things to/from the autograder. Final grades will be based on a different autograder.
#
# Once you are ready, create a zip file of the homework folder. Change the name of the file to 'LASTNAME_NAME_HW0.zip', and submit it on Canvas.

# %%
importlib.reload(autograder)
autograder.autograde()
